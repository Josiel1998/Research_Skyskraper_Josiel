# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Get Data
df = pd.read_csv("./data/TwitterDataset.csv")
df.head()
# Out:
#    likes  parent_tweet_id  retweets  tweet_date tweet_handle  \
# 0    0.0     1.366494e+18       0.0  2021-03-02       amazon
# 1    0.0     1.366803e+18       0.0  2021-03-02       amazon
# 2    0.0     1.365764e+18       0.0  2021-03-02       amazon
# 3    1.0     1.366783e+18       0.0  2021-03-02       amazon
# 4    2.0     1.366797e+18       0.0  2021-03-02       amazon
#
#               tweet_id                                         tweet_text  \
# 0  1366811295404670978  @Prinxofdarkness Thanks for contacting us back...
# 1  1366805720579133444  @taliahreene We would've made the same move. 👍...
# 2  1366805543382319106  @livvibarns Of course! Please keep an eye on y...
# 3  1366805462952378372  @TheCleftonTwain We miss you too Sean! We miss...
# 4  1366801584538140674  @taliahreene The Clash once faced the same dil...
#
#   tweet_time                                          tweet_url  \
# 0   18:03:01  https://twitter.com/elonmusk/status/1366811295...
# ...
